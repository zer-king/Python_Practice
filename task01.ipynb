# %%
import pandas as pd
import numpy as np

# Load data from a CSV file
csv_file_path = "csv_data.csv"
# Read the CSV file into a DataFrame and you don't need to specify the delimiter if it's a comma and python uses relative paths by default so if in same file don't need to specify full path
# if the file is outside the current working directory you can specify the full path or 
# change the working directory using os.chdir() before reading the file to avoid FileNotFoundError and ensure the file exists at the specified location.
# it would look like this: data = pd.read_csv("xxxx/xxxx/xxxx/xxxx/csv_data.csv") but what if i need my file path to be hidden for security reasons?
# then you can use environment variables or configuration files to store sensitive paths and retrieve them in your code.
# for example using os module to get environment variable
# import os
# csv_file_path = os.getenv("CSV_FILE_PATH") 
# data = pd.read_csv(csv_file_path, delimiter=',')
# and how do i set up the getenv variable?
# you can set environment variables in your operating system settings or use a .env file with the python-dotenv package to load them automatically. 
# Make sure to install python-dotenv via pip if you choose that method.
# pip install python-dotenv   
data = pd.read_csv(csv_file_path)
print(data)
# Out:
#     Age       Name
# 0    98        Ava
# 1    52       Liam
# 2    89     Sophia
# 3     2       Noah
# 4     5   Isabella
# 5    88      Ethan
# 6    93        Mia
# 7    27      Lucas
# 8    84     Amelia
# 9    49     Oliver
# 10    4  Charlotte
# 11   64     Elijah
# 12   94     Harper
# 13   21      James
# 14   54       Aria
# 15   96   Benjamin
# 16   19      Layla
# 17    9      Henry
# 18   81   Scarlett
# 19   72       Jack
