# %%
import numpy as np
import pandas as pd

df=pd.read_csv('construction_data.csv')
print(df.head())
filterArray=['Labour','Materials']
dfFiltered=df[df['Category'].isin(filterArray)].count
print(dfFiltered)
# Out:
#      Project        Phase       Category Location        Date    Cost
# 0  Project D   Deployment         Labour  Chicago  2025-05-29  3636.0
# 1  Project A      Testing      Materials  Houston  2025-03-23  6924.0
# 2  Project A      Testing  Miscellaneous  Chicago  2025-06-06  9950.0
# 3  Project C      Testing      Equipment  Houston  2025-03-25  9528.0
# 4  Project B  Development      Equipment  Chicago  2025-06-05  5452.0
# <bound method DataFrame.count of       Project        Phase   Category     Location        Date    Cost
# 0   Project D   Deployment     Labour      Chicago  2025-05-29  3636.0
# 1   Project A      Testing  Materials      Houston  2025-03-23  6924.0
# 9   Project D  Development     Labour     New York  2025-09-07  4635.0
# 11  Project D     Planning     Labour      Chicago  2025-02-08  2073.0
# 13  Project A      Testing  Materials     New York  2025-05-26  1338.0
# 14  Project B     Planning  Materials     New York  2025-07-04  6094.0
# ...
